# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# # 1

# %%
ntrial = 10000
prob = .3
binom = np.random.binomial(ntrial, prob, 100)
dist1 = (binom - binom.mean())/binom.std()
plt.hist(dist1, bins=25)
plt.show()

# %%
fig =sm.qqplot(dist1, line='45')
plt.show()

# %% [markdown]
# Points that fall below (above) the y=x line imply that my binomial dist is more (less) dispersed for those quantiles than those of the normal distribution it's compared to.
#
# The points tend to be further from the 45deg line at the upper and lower quantiles than near the median, which implies that the binomial distribution is a worse approximation of a normal distribution the further out along the tales one goes.

# %% [markdown]
# # 2

# %%
def plothist(mu, sigma, Ngen):
    out = []
    for _ in range(Ngen):
        dist= np.random.normal(loc=mu, scale=sigma, size=1000)
        out.append(dist.mean())
    ttl = f'{Ngen} means of N({mu},{sigma})x1000'
    plt.hist(np.array(out))
    plt.title(ttl)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2, 1)
plothist(10, 2, 50)
plt.subplot(1,2, 2)
plothist(10, 1, 1000)
plt.show()

# %% [markdown]
# The variable sampled 1000 times has a distribution closer to the normal distribution than the one sampled only 50 times, which supports the central limit theorem
